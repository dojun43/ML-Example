# %% [markdown]
# <a href="https://colab.research.google.com/github/dojun43/ML-Example/blob/master/Scaling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import datasets
from sklearn.datasets import load_boston
from sklearn.preprocessing import StandardScaler 
from sklearn.preprocessing import MinMaxScaler 

import warnings 
warnings.filterwarnings('ignore')

# %% [markdown]
# # Data

# %%
boston_data = datasets.load_boston()
data = pd.DataFrame(boston_data['data'], columns=boston_data['feature_names'])
target = pd.DataFrame(boston_data['target'], columns=['Target'])
df = pd.concat([data, target], axis=1)

# %%
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT  Target
# 0       15.3  396.90   4.98    24.0
# ...

# %% [markdown]
# # StandardScaler

# %% [markdown]
# - transform

# %%
X_col_list = ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
       'PTRATIO', 'B', 'LSTAT']

y_col_list = ['Target']

X = df.loc[:,X_col_list]
y = df.loc[:,y_col_list]

#scaler 생성 
X_scaler = StandardScaler().fit(X) 
y_scaler = StandardScaler().fit(y)

X = X_scaler.transform(X)
y = y_scaler.transform(y)

# %%
X = pd.DataFrame(X, columns = X_col_list)
X.head()
# Out:
#        CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# 0 -0.419782  0.284830 -1.287909 -0.272599 -0.144217  0.413672 -0.120013
# 1 -0.417339 -0.487722 -0.593381 -0.272599 -0.740262  0.194274  0.367166
# 2 -0.417342 -0.487722 -0.593381 -0.272599 -0.740262  1.282714 -0.265812
# 3 -0.416750 -0.487722 -1.306878 -0.272599 -0.835284  1.016303 -0.809889
# 4 -0.412482 -0.487722 -1.306878 -0.272599 -0.835284  1.228577 -0.511180
#
#         DIS       RAD       TAX   PTRATIO         B     LSTAT
# 0  0.140214 -0.982843 -0.666608 -1.459000  0.441052 -1.075562
# 1  0.557160 -0.867883 -0.987329 -0.303094  0.441052 -0.492439
# 2  0.557160 -0.867883 -0.987329 -0.303094  0.396427 -1.208727
# 3  1.077737 -0.752922 -1.106115  0.113032  0.416163 -1.361517
# 4  1.077737 -0.752922 -1.106115  0.113032  0.441052 -1.026501

# %%
y = pd.DataFrame(y, columns = y_col_list)
y.head()
# Out:
#      Target
# 0  0.159686
# 1 -0.101524
# 2  1.324247
# 3  1.182758
# 4  1.487503

# %% [markdown]
# - inverse_transform

# %%
X = X_scaler.inverse_transform(X)
y = y_scaler.inverse_transform(y)

# %%
X = pd.DataFrame(X, columns = X_col_list)
X.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %%
y = pd.DataFrame(y, columns = y_col_list)
y.head()
# Out:
#    Target
# 0    24.0
# 1    21.6
# 2    34.7
# 3    33.4
# 4    36.2

# %% [markdown]
# # MinMaxScaler

# %% [markdown]
# - transform

# %%
X_col_list = ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
       'PTRATIO', 'B', 'LSTAT']

y_col_list = ['Target']

X = df.loc[:,X_col_list]
y = df.loc[:,y_col_list]

#scaler 생성 
X_scaler = MinMaxScaler().fit(X) 
y_scaler = MinMaxScaler().fit(y)

X = X_scaler.transform(X)
y = y_scaler.transform(y)

# %%
X = pd.DataFrame(X, columns = X_col_list)
X.head()
# Out:
#        CRIM    ZN     INDUS  CHAS       NOX        RM       AGE       DIS  \
# 0  0.000000  0.18  0.067815   0.0  0.314815  0.577505  0.641607  0.269203
# 1  0.000236  0.00  0.242302   0.0  0.172840  0.547998  0.782698  0.348962
# 2  0.000236  0.00  0.242302   0.0  0.172840  0.694386  0.599382  0.348962
# 3  0.000293  0.00  0.063050   0.0  0.150206  0.658555  0.441813  0.448545
# 4  0.000705  0.00  0.063050   0.0  0.150206  0.687105  0.528321  0.448545
#
#         RAD       TAX   PTRATIO         B     LSTAT
# 0  0.000000  0.208015  0.287234  1.000000  0.089680
# 1  0.043478  0.104962  0.553191  1.000000  0.204470
# 2  0.043478  0.104962  0.553191  0.989737  0.063466
# 3  0.086957  0.066794  0.648936  0.994276  0.033389
# 4  0.086957  0.066794  0.648936  1.000000  0.099338

# %%
y = pd.DataFrame(y, columns = y_col_list)
y.head()
# Out:
#      Target
# 0  0.422222
# 1  0.368889
# 2  0.660000
# 3  0.631111
# 4  0.693333

# %% [markdown]
# - inverse_transform

# %%
X = X_scaler.inverse_transform(X)
y = y_scaler.inverse_transform(y)

# %%
X = pd.DataFrame(X, columns = X_col_list)
X.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %%
y = pd.DataFrame(y, columns = y_col_list)
y.head()
# Out:
#    Target
# 0    24.0
# 1    21.6
# 2    34.7
# 3    33.4
# 4    36.2
